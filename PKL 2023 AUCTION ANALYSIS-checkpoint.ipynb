# %% [markdown]
# # PKL 2023 AUCTION ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir("C:\\Users\\Aryan Mahagaonkar\\Desktop\\py")

# %%
os.listdir()
# Out:
# ['countrystats.csv',
#  'deliveries - Copy.csv',
#  'deliveries.csv',
#  'googleplaystore.csv',
#  'ICCTestBat3001.xlsx',
#  'ICCTestBattingFigures.csv',
#  'IPL2025Batters.csv',
#  'matches.csv',
#  'PKL_2023_aunction_dataset.csv',
#  'Sample - Superstore.csv',
#  'Videos - Shortcut.lnk',
#  'world-db']

# %%
pkl=pd.read_csv("PKL_2023_aunction_dataset.csv")
pkl
# Out:
#      Unnamed: 0          Player Name     Category  Base Price Sold Price  \
# 0             0       Maninder Singh       Raider      30 lac    2.12 cr
# 1             1          Nitin Rawal  All Rounder      20 lac     30 lac
# 2             2       Shubham Shinde     Defender      20 lac  32.25 lac
# 3             3      Shrikant Jadhav     Defender      20 lac  35.25 lac
# 4             4  Bhoir Akshay Bharat  All Rounder      13 lac     13 lac
# ..          ...                  ...          ...         ...        ...
# 238         238     Shivam Chaudhary       Raider         NYP   Retained
# 239         239         Nitesh Kumar     Defender  Category B   Retained
# 240         240                Sumit     Defender  Category A   Retained
# 241         241           Ashu Singh     Defender  Category B   Retained
# 242         242               Hitesh     Defender         NYP   Retained
#
#            2023 Team
# 0    Bengal Warriors
# 1    Bengal Warriors
# 2    Bengal Warriors
# ...

# %%
pkl.info()
pkl.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   243 non-null    int64
#  1   Player Name  243 non-null    object
#  2   Category     243 non-null    object
#  3   Base Price   243 non-null    object
#  4   Sold Price   118 non-null    float64
#  5   2023 Team    243 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 11.5+ KB
# Unnamed: 0       0
# Player Name      0
# Category         0
# Base Price       0
# Sold Price     125
# 2023 Team        0
# dtype: int64

# %%
pkl.shape
# Out:
# (243, 6)

# %%
pkl.columns
# Out:
# Index(['Unnamed: 0', 'Player Name', 'Category', 'Base Price', 'Sold Price',
#        '2023 Team'],
#       dtype='object')

# %%
pkl.describe()
# Out:
#        Unnamed: 0
# count  243.000000
# mean   121.000000
# std     70.292247
# min      0.000000
# 25%     60.500000
# 50%    121.000000
# 75%    181.500000
# max    242.000000

# %% [markdown]
# # List Of Player Sold,Retained,& Sign Contract in PKL 2023 Auction

# %%
pkl["Player Name"].unique()
# Out:
# array(['Maninder Singh', 'Nitin Rawal', 'Shubham Shinde',
#        'Shrikant Jadhav', 'Bhoir Akshay Bharat', 'Akshay Kumar',
#        'Akshay Jaywant Bodake', 'Vishwas S', 'Nitin Kumar',
#        'Aslam Saja Mohamed Thambi', 'Chai-Ming Chang',
#        'Dipak Arjun Shinde', 'Aditya S. Shinde', 'Shreyas Umardand',
#        'Maharudra Garje', 'Vaibhav Bhausaheb Garje', 'R Guhan',
#        'Suyog Baban Gaikar', 'Parshant Kumar', 'Sachin Narwal', 'Vishal',
#        'Vikash Khandola', 'Ran Singh', 'Sunder',
#        'Ponparthiban Subramanian', 'Surjeet Singh', 'Abhishek Singh',
#        'Banty', 'Monu', 'Sushil', 'Ankit', 'Md. Liton Ali',
#        'Piotr Pamulak', 'Rakshith', 'Rohit Kumar', 'Arulnanthababu',
#        'Parteek', 'Aditya Power', 'Akshit', 'Saurabh Nandal', 'Bharat',
#        'Neeraj Narwal', 'Aman', 'Yash Hooda', 'Vishal Bhardwaj', 'Sunil',
#        'Ashu Malik', 'Meetu', 'Nitin Chandel', 'Balasaheb Shahaji Jadhav',
# ...

# %% [markdown]
# # No.Of Players Sold,Retained,& Sign Contract

# %%
players_sold=pkl["Player Name"].unique()
len(players_sold)
# Out:
# 228

# %% [markdown]
# # There Are Three Category of player :-
# #### 1.raiders
# #### 2.defenders
# #### 3.all rounders

# %% [markdown]
# ### List Of Raiders

# %%
pkl[pkl["Category"]=="Raider"]
# Out:
#      Unnamed: 0                Player Name Category  Base Price  Sold Price  \
# 0             0             Maninder Singh   Raider      30 lac        2.12
# 6             6      Akshay Jaywant Bodake   Raider      13 lac       13.00
# 7             7                  Vishwas S   Raider      13 lac       13.00
# 8             8                Nitin Kumar   Raider       9 lac       32.20
# 9             9  Aslam Saja Mohamed Thambi   Raider      13 lac       13.00
# ..          ...                        ...      ...         ...         ...
# 234         234              Surender Gill   Raider  Category A         NaN
# 235         235                    Mahipal   Raider         NYP         NaN
# 236         236                 Anil Kumar   Raider         NYP         NaN
# 237         237               Gagana Gowda   Raider         NYP         NaN
# 238         238           Shivam Chaudhary   Raider         NYP         NaN
#
#            2023 Team
# 0    Bengal Warriors
# ...

# %% [markdown]
# ###  List Of Defenders

# %%
pkl[pkl["Category"]=="Defender"]
# Out:
#      Unnamed: 0         Player Name  Category  Base Price Sold Price  \
# 2             2      Shubham Shinde  Defender      20 lac  32.25 lac
# 3             3     Shrikant Jadhav  Defender      20 lac  35.25 lac
# 5             5        Akshay Kumar  Defender      13 lac     13 lac
# 11           11  Dipak Arjun Shinde  Defender         NYP   Retained
# 12           12    Aditya S. Shinde  Defender         NYP   Retained
# ..          ...                 ...       ...         ...        ...
# 229         229      Harendra Kumar  Defender      13 lac     13 lac
# 239         239        Nitesh Kumar  Defender  Category B   Retained
# 240         240               Sumit  Defender  Category A   Retained
# 241         241          Ashu Singh  Defender  Category B   Retained
# 242         242              Hitesh  Defender         NYP   Retained
#
#            2023 Team
# 2    Bengal Warriors
# 3    Bengal Warriors
# 5    Bengal Warriors
# 11   Bengal Warriors
# 12   Bengal Warriors
# ...

# %% [markdown]
# ### List Of All Rounders

# %%
pkl[pkl["Category"]=="All Rounder"]
# Out:
#      Unnamed: 0                  Player Name     Category Base Price  \
# 1             1                  Nitin Rawal  All Rounder     20 lac
# 4             4          Bhoir Akshay Bharat  All Rounder     13 lac
# 19           19                Sachin Narwal  All Rounder     20 lac
# 22           22                    Ran Singh  All Rounder     13 lac
# 50           50                Akash Prasher  All Rounder      9 lac
# 65           65                  Rohit Gulia  All Rounder     30 lac
# 66           66  Mohammad Esmaeil Nabibakhsh  All Rounder     20 lac
# 67           67                 Arkam Shaikh  All Rounder     20 lac
# 69           69                     Balaji D  All Rounder     13 lac
# 70           70                 Vikas Jaglan  All Rounder     13 lac
# 75           75               Jitender Yadav  All Rounder      9 lac
# 84           84                       Ashish  All Rounder     20 lac
# 125         125                        Rohit  All Rounder     13 lac
# ...

# %% [markdown]
# # List Of Players Retained By Teams

# %%
pkl[pkl['Sold Price']=="Retained"]
# Out:
#      Unnamed: 0              Player Name  Category  Base Price Sold Price  \
# 11           11       Dipak Arjun Shinde  Defender         NYP   Retained
# 12           12         Aditya S. Shinde  Defender         NYP   Retained
# 13           13         Shreyas Umardand  Defender         NYP   Retained
# 14           14          Maharudra Garje    Raider         NYP   Retained
# 15           15  Vaibhav Bhausaheb Garje  Defender         NYP   Retained
# ..          ...                      ...       ...         ...        ...
# 238         238         Shivam Chaudhary    Raider         NYP   Retained
# 239         239             Nitesh Kumar  Defender  Category B   Retained
# 240         240                    Sumit  Defender  Category A   Retained
# 241         241               Ashu Singh  Defender  Category B   Retained
# 242         242                   Hitesh  Defender         NYP   Retained
#
#            2023 Team
# 11   Bengal Warriors
# 12   Bengal Warriors
# ...

# %% [markdown]
# # List Of NYP[NEW YOUNG PLAYERS] Players By Teams

# %%
pkl[pkl['Base Price']=="NYP"]
# Out:
#      Unnamed: 0              Player Name  Category Base Price Sold Price  \
# 11           11       Dipak Arjun Shinde  Defender        NYP   Retained
# 12           12         Aditya S. Shinde  Defender        NYP   Retained
# 13           13         Shreyas Umardand  Defender        NYP   Retained
# 14           14          Maharudra Garje    Raider        NYP   Retained
# 15           15  Vaibhav Bhausaheb Garje  Defender        NYP   Retained
# ..          ...                      ...       ...        ...        ...
# 235         235                  Mahipal    Raider        NYP   Retained
# 236         236               Anil Kumar    Raider        NYP   Retained
# 237         237             Gagana Gowda    Raider        NYP   Retained
# 238         238         Shivam Chaudhary    Raider        NYP   Retained
# 242         242                   Hitesh  Defender        NYP   Retained
#
#            2023 Team
# 11   Bengal Warriors
# 12   Bengal Warriors
# 13   Bengal Warriors
# ...

# %% [markdown]
# # Players Brought By Teams In PKL 2023 Auction

# %%
bengal_warriors = pkl[pkl['2023 Team'].str.contains('bengal warriors', case=False, na=False)]
bengal_warriors['Sold Price'] = pd.to_numeric(bengal_warriors['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)  
plt.figure(figsize=(10,6))
plt.bar(bengal_warriors['Player Name'], bengal_warriors['Sold Price'], color='skyblue')
plt.title("Players Sold to Bengal Warriors - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by  Bengal Warriors  im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\2968978545.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bengal_warriors['Sold Price'] = pd.to_numeric(bengal_warriors['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
bengaluru_bulls = pkl[pkl['2023 Team'].str.contains('bengaluru bulls', case=False, na=False)]
bengaluru_bulls['Sold Price'] = pd.to_numeric(bengaluru_bulls['Sold Price'], errors='coerce')#Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(10,6))
plt.bar(bengaluru_bulls_numeric['Player Name'], bengaluru_bulls_numeric['Sold Price'], color='red')
plt.title("Players Sold to Bengaluru Bulls - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by  Bengaluru Bulls im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\1251611774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bengaluru_bulls['Sold Price'] = pd.to_numeric(bengaluru_bulls['Sold Price'], errors='coerce')#Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
dabang_delhi = pkl[pkl['2023 Team'].str.contains('dabang delhi.k.c', case=False, na=False)]
dabang_delhi['Sold Price'] = pd.to_numeric(dabang_delhi['Sold Price'], errors='coerce') #Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(10,6))
plt.bar(dabang_delhi_numeric['Player Name'], dabang_delhi_numeric['Sold Price'], color='darkblue')
plt.title("Players Sold to Dabang Delhi K.C - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by  Dabang Delhi K.C im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\4006465992.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dabang_delhi['Sold Price'] = pd.to_numeric(dabang_delhi['Sold Price'], errors='coerce') #Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
gujarat_giants = df[df['2023 Team'].str.contains('gujarat giants', case=False, na=False)]
gujarat_giants['Sold Price'] = pd.to_numeric(gujarat_giants['Sold Price'], errors='coerce')#Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(10,6))
plt.bar(gujarat_giants['Player Name'], gujarat_giants['Sold Price'], color='red')
plt.title("Players Sold to Gujarat Giants - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by  Gujarat Giants  im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\3389799936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gujarat_giants['Sold Price'] = pd.to_numeric(gujarat_giants['Sold Price'], errors='coerce')#Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
haryana_steelers = pkl[pkl['2023 Team'].str.contains('haryanasteelers', case=False, na=False)]
haryana_steelers['Sold Price'] = pd.to_numeric(haryana_steelers['Sold Price'], errors='coerce')#Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(10,6))
plt.bar(haryana_steelers['Player Name'], haryana_steelers['Sold Price'], color='blue')
plt.title("Players Sold to Haryana Steelers - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by  Haryana Steelers  im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\1449651649.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   haryana_steelers['Sold Price'] = pd.to_numeric(haryana_steelers['Sold Price'], errors='coerce')#Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
jaipur_pp = df[df['2023 Team'].str.contains('jaipur pink panthers', case=False, na=False)]
jaipur_pp['Sold Price'] = pd.to_numeric(jaipur_pp['Sold Price'], errors='coerce')#  Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(10,6))
plt.bar(jaipur_pp['Player Name'], jaipur_pp['Sold Price'], color='pink')
plt.title("Players Sold to Jaipur Pink Panthers - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by  Jaipur Pink Panthers im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\660121880.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jaipur_pp['Sold Price'] = pd.to_numeric(jaipur_pp['Sold Price'], errors='coerce')#  Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
patna = pkl[pkl['2023 Team'].str.contains('patna pirates', case=False, na=False)]
patna['Sold Price'] = pd.to_numeric(patna['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(10,6))
plt.bar(patna['Player Name'], patna['Sold Price'], color='green')
plt.title("Players Sold to Patna Pirates - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by  Patna Pirates im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\3733415288.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   patna['Sold Price'] = pd.to_numeric(patna['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
Puneri_Paltan = pkl[pkl['2023 Team'].str.contains('puneri paltan', case=False, na=False)]
Puneri_Paltan['Sold Price'] = pd.to_numeric(Puneri_Paltan['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(8,5))
plt.bar(Puneri_Paltan['Player Name'], Puneri_Paltan['Sold Price'], color='orange')
plt.title("Players Sold to puneri paltan")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Players brought by Puneri_Paltan im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\958059061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Puneri_Paltan['Sold Price'] = pd.to_numeric(Puneri_Paltan['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
Tamil_Thalaivas = pkl[pkl['2023 Team'].str.contains('tamil thalaivas', case=False, na=False)]
Tamil_Thalaivas['Sold Price'] = pd.to_numeric(Tamil_Thalaivas['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(10,6))
plt.bar(Tamil_Thalaivas['Player Name'], Tamil_Thalaivas['Sold Price'], color='gold')
plt.title("Players Sold toTamil Thalaivas- PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by Tamil_Thalaivas im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\1414313467.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tamil_Thalaivas['Sold Price'] = pd.to_numeric(Tamil_Thalaivas['Sold Price'], errors='coerce')

# %%
telugu = pkl[pkl['2023 Team'].str.contains('telugu titans', case=False, na=False)]
telugu['Sold Price'] = pd.to_numeric(telugu['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(10,6))
plt.bar(telugu['Player Name'], telugu['Sold Price'], color='yellow')
plt.title("Players Sold to Telugu Titans - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by Telugu Titans im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\4281557326.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   telugu['Sold Price'] = pd.to_numeric(telugu['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
u_mumba = pkl[pkl['2023 Team'].str.contains('u mumba', case=False, na=False)]
u_mumba['Sold Price'] = pd.to_numeric(u_mumba['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.figure(figsize=(8,5))
plt.bar(u_mumba['Player Name'], u_mumba['Sold Price'], color='orange')
plt.title("Players Sold to U Mumba")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# Players brought by umumba im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\2115626466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   u_mumba['Sold Price'] = pd.to_numeric(u_mumba['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %%
upyoddhas = pkl[pkl['2023 Team'].str.contains('u.p. yoddhas', case=False, na=False)]
upyoddhas['Sold Price'] = pd.to_numeric(upyoddhas['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)
plt.bar(upyoddhas['Player Name'], upyoddhas['Sold Price'], color='brown')
plt.title("Players Sold to U.P. Yoddhas - PKL 2023 Auction")
plt.xlabel("Player Name")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Players brought by upyoddhas im pkl 2023 auction
# Out:
# C:\Users\Aryan Mahagaonkar\AppData\Local\Temp\ipykernel_9940\133930046.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upyoddhas['Sold Price'] = pd.to_numeric(upyoddhas['Sold Price'], errors='coerce')# Convert Sold Price to numeric (non-numeric like Retained/NYP → NaN)

# %% [markdown]
# # Auction Summary

# %% [markdown]
# #### Top 5 Highest Sold Raiders - PKL 2023 Auction

# %%
top5_raiders = (pkl[pkl['Category'].str.lower() == 'raider'].sort_values(by='Sold Price', ascending=False).head(5))
plt.figure(figsize=(8,5))
sns.barplot(data=top5_raiders, x='Player Name', y='Sold Price', hue='2023 Team', palette='viridis')
plt.title("Top 5 Highest Sold Raiders - PKL 2023 Auction")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#this graph shows top 5 coastlist raiders.

# %% [markdown]
# #### Top 5 Highest Sold Defenders - PKL 2023 Auction

# %%
pkl['Sold Price'] = pd.to_numeric(pkl['Sold Price'], errors='coerce')
top5_Defender = defenders.sort_values(by='Sold Price', ascending=False).head(5)
plt.figure(figsize=(10,5))
sns.barplot(data=top5_Defender, x='Player Name', y='Sold Price', hue='2023 Team', palette='viridis')
plt.title("Top 5 Highest Sold Defenders - PKL 2023 Auction")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#this graph shows top 5 coastlist defenders.

# %% [markdown]
# #### Top 5 Highest Sold all rounders - PKL 2023 Auction

# %%
top5_AllRounder = (pkl[pkl['Category'].str.lower() == 'all rounder'].sort_values(by='Sold Price', ascending=False).head())
plt.figure(figsize=(10,5))
sns.barplot(data=top5_AllRounder, x='Player Name', y='Sold Price', hue='2023 Team', palette='viridis')
plt.title("Top 5 Highest Sold All Rounder in PKL 2023 Auction")
plt.ylabel("Sold Price (in Lakh)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#this graph shows top 5 coastlist all rounders.

# %%
team_counts = df['2023 Team'].value_counts().reset_index()
team_counts.columns = ['Team', 'Number of Players']

plt.figure(figsize=(10,6))
sns.lineplot(data=team_counts, x='Team', y='Number of Players', marker='o', linewidth=2, color='green')
plt.title("Number of Players In Each Team  in PKL 2023 Auction")
plt.ylabel("Number of Players")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#this graph shows the no.of players in each team

# %%
category_counts = pkl['Base Price'].value_counts().loc[['Category A','Category B','Category C']]

plt.plot(category_counts.index, category_counts.values, marker='o', linestyle='-', linewidth=2)
plt.title("Player Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Number of Players")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

#This graph shows the no .of players sold from categogry a,b,c in pkl 2023 auction
#this categories are based on players performance
# [categogry a contains : high performing players,categogry b:contain : players who have decent performance in last season,categogry c contains : NYP(New Young Player)or the players who haven't made much impact in pkl]

# %%
team_counts = pkl['2023 Team'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(team_counts, labels=team_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Proportion of Players Sold per Team - PKL 2023 Auction")
plt.axis('equal') 
plt.show()

# this graph shows the proportion of players sold per team

# %% [markdown]
# ## Full Squad Of Teams After Auction

# %%
pkl["Sold Price"] = pkl["Sold Price"].replace(np.nan, "Retained")# replace NAN values with Retained

# %%
pkl[pkl["2023 Team"]=="Bengaluru Bulls"]
# Out:
#     Unnamed: 0               Player Name     Category  Base Price Sold Price  \
# 19          19             Sachin Narwal  All Rounder      20 lac      23.25
# 20          20                    Vishal     Defender      20 lac       20.0
# 21          21           Vikash Khandola       Raider      20 lac      55.25
# 22          22                 Ran Singh  All Rounder      13 lac       13.0
# 23          23                    Sunder     Defender      13 lac       13.0
# 24          24  Ponparthiban Subramanian     Defender      13 lac       19.2
# 25          25             Surjeet Singh     Defender      13 lac       14.2
# 26          26            Abhishek Singh       Raider      13 lac       14.0
# 27          27                     Banty       Raider      13 lac       13.0
# 28          28                      Monu       Raider      13 lac       24.1
# 29          29                    Sushil       Raider      13 lac       13.0
# ...

# %%
pkl[pkl["2023 Team"]=="Bengal Warriors"]
# Out:
#     Unnamed: 0                Player Name     Category Base Price Sold Price  \
# 0            0             Maninder Singh       Raider     30 lac       2.12
# 1            1                Nitin Rawal  All Rounder     20 lac       30.0
# 2            2             Shubham Shinde     Defender     20 lac      32.25
# 3            3            Shrikant Jadhav     Defender     20 lac      35.25
# 4            4        Bhoir Akshay Bharat  All Rounder     13 lac       13.0
# 5            5               Akshay Kumar     Defender     13 lac       13.0
# 6            6      Akshay Jaywant Bodake       Raider     13 lac       13.0
# 7            7                  Vishwas S       Raider     13 lac       13.0
# 8            8                Nitin Kumar       Raider      9 lac       32.2
# 9            9  Aslam Saja Mohamed Thambi       Raider     13 lac       13.0
# 10          10            Chai-Ming Chang       Raider     13 lac       13.0
# ...

# %%
pkl[pkl["2023 Team"]=="Dabang Delhi.K.C"]
# Out:
#     Unnamed: 0               Player Name     Category  Base Price Sold Price  \
# 44          44           Vishal Bhardwaj     Defender      20 lac       20.0
# 45          45                     Sunil     Defender      20 lac       20.0
# 46          46                Ashu Malik       Raider      20 lac      96.25
# 47          47                     Meetu       Raider      20 lac       93.0
# 48          48             Nitin Chandel     Defender      13 lac       13.0
# 49          49  Balasaheb Shahaji Jadhav     Defender      13 lac       13.0
# 50          50             Akash Prasher  All Rounder       9 lac        9.0
# 51          51                   Vikrant     Defender       9 lac        9.0
# 52          52                  Felix Li     Defender      13 lac       13.0
# 53          53            Yuvraj Pandeya     Defender      13 lac       13.0
# 54          54                     Mohit     Defender       9 lac        9.0
# ...

# %%
pkl[pkl["2023 Team"]=="Gujarat Giants"]
# Out:
#     Unnamed: 0                  Player Name     Category  Base Price  \
# 64          64              Fazel Atrachali     Defender      30 lac
# 65          65                  Rohit Gulia  All Rounder      30 lac
# 66          66  Mohammad Esmaeil Nabibakhsh  All Rounder      20 lac
# 67          67                 Arkam Shaikh  All Rounder      20 lac
# 68          68                       Sombir     Defender      20 lac
# 69          69                     Balaji D  All Rounder      13 lac
# 70          70                 Vikas Jaglan  All Rounder      13 lac
# 71          71                 Sourav Gulia     Defender      13 lac
# 72          72        Deepak Rajender Singh     Defender      13 lac
# 73          73                   Ravi Kumar     Defender      13 lac
# 74          74                     More G B       Raider      13 lac
# 75          75               Jitender Yadav  All Rounder       9 lac
# 76          76                       Nitesh     Defender       9 lac
# ...

# %%
pkl[pkl["2023 Team"]=="HaryanaSteelers"]
# Out:
#      Unnamed: 0             Player Name     Category  Base Price Sold Price  \
# 84           84                  Ashish  All Rounder      20 lac      23.25
# 85           85         Chandran Ranjit       Raider      20 lac       62.0
# 86           86  Siddharth Sirish Desai       Raider      20 lac        1.0
# 87           87                   Mohit     Defender      13 lac       20.0
# 88           88           Rahul Sethpal     Defender      13 lac       40.7
# 89           89      Himanshu Choudhary     Defender       9 lac        9.0
# 90           90        Ravindra Chouhan     Defender       9 lac        9.0
# 91           91    Ghanshyam Roka Magar       Raider      13 lac       13.0
# 92           92           Hasan Balbool       Raider      13 lac       13.0
# 93           93            K. Prapanjan       Raider  Category C   Retained
# 94           94                   Vinay       Raider  Category C   Retained
# ...

# %%
pkl[pkl["2023 Team"]=="Jaipur Pink Panthers"]
# Out:
#      Unnamed: 0                  Player Name  Category  Base Price Sold Price  \
# 105         105                        Sumit  Defender      13 lac       13.0
# 106         106                 Lucky Sharma  Defender      13 lac       13.0
# 107         107                       Lavish  Defender      13 lac       13.0
# 108         108                      Navneet    Raider      13 lac       13.0
# 109         109              Rahul Chaudhari    Raider      13 lac       13.0
# 110         110                   Shashank B    Raider       9 lac        9.0
# 111         111  Amir Hossein Mohammadmaleki    Raider      13 lac       13.0
# 112         112               Bhavani Rajput    Raider  Category C   Retained
# 113         113                Arjun Deshwal    Raider  Category A   Retained
# 114         114                V Ajith Kumar    Raider  Category B   Retained
# 115         115                       Devank    Raider         NYP   Retained
# ...

# %%
pkl[pkl["2023 Team"]=="Patna Pirates"]
# Out:
#      Unnamed: 0             Player Name     Category  Base Price Sold Price  \
# 124         124                 Manjeet       Raider      30 lac       92.0
# 125         125                   Rohit  All Rounder      13 lac       16.0
# 126         126      Sajin Chandrasekar  All Rounder      13 lac       13.0
# 127         127                 Krishan     Defender      13 lac       17.2
# 128         128           Rakesh Narwal       Raider      13 lac       13.0
# 129         129                  Sanjay     Defender      13 lac       13.0
# 130         130                   Ankit  All Rounder       9 lac       31.5
# 131         131            Deepak Kumar     Defender       9 lac        9.0
# 132         132  Daniel Omondi Odhiambo  All Rounder      13 lac       13.0
# 133         133          Zheng-Wei Chen       Raider      13 lac       13.0
# 134         134      Mahendra Choudhary     Defender       9 lac        9.0
# ...

# %%
pkl[pkl["2023 Team"]=="Puneri Paltan"]
# Out:
#      Unnamed: 0                     Player Name     Category  Base Price  \
# 146         146  Mohammadreza Shadloui Chiyaneh  All-Rounder      30 lac
# 147         147           Ahmed Mustafa Enamdar  All-Rounder       9 lac
# 148         148                          Ishwar     Defender       9 lac
# 149         149                         Hardeep     Defender       9 lac
# 150         150                Vahid RezaEimehr     Defender      13 lac
# 151         151                   Pankaj Mohite       Raider  Category C
# 152         152                     Mohit Goyat       Raider  Category B
# 153         153                         Nitin R       Raider         NYP
# 154         154                    Akash Shinde       Raider  Category B
# 155         155                   Aditya Shinde       Raider         NYP
# 156         156                   Sanket Sawant     Defender  Category C
# 157         157               Abinesh Nadarajan     Defender  Category C
# ...

# %%
pkl[pkl["2023 Team"]=="Tamil Thalaivas"]
# Out:
#      Unnamed: 0                 Player Name     Category  Base Price  \
# 164         164              Himanshu Singh       Raider      13 lac
# 165         165                 Selvamani K       Raider      13 lac
# 166         166                       Ritik  All Rounder       9 lac
# 167         167      Masanamuthu Lakshnanan       Raider       9 lac
# 168         168               Satish Kannan       Raider       9 lac
# 169         169         Amirhossein Bastami     Defender      13 lac
# 170         170  Mohammadreza Kaboudrahangi     Defender      13 lac
# 171         171               Ajinkya Pawar       Raider  Category B
# 172         172               Vishal Chahal       Raider         NYP
# 173         173             Himanshu Narwal       Raider         NYP
# 174         174                 Nitin Singh       Raider         NYP
# 175         175                    Narender       Raider         NYP
# 176         176                       Jatin       Raider         NYP
# ...

# %%
pkl[pkl["2023 Team"]=="Telugu Titans"]
# Out:
#      Unnamed: 0            Player Name     Category  Base Price Sold Price  \
# 185         185   Pawan Kumar Sehrawat       Raider      20 lac      2.605
# 186         186  Shankar Bhimraj Gadai  All-Rounder      13 lac       13.0
# 187         187          Omkar R. More  All-Rounder       9 lac        9.0
# 188         188          Gaurav Dahiya     Defender       9 lac        9.0
# 189         189   Ajit Pandurang Pawar     Defender       9 lac        9.0
# 190         190                  Mohit     Defender       9 lac        9.0
# 191         191        Robin Chaudhary       Raider       9 lac        9.0
# 192         192    Hamid Mirzaei Nader  All-Rounder      13 lac       13.0
# 193         193          Milad Jabbari     Defender      13 lac       13.0
# 194         194                Rajnish       Raider  Category C   Retained
# 195         195                  Vinay       Raider         NYP   Retained
# ...

# %%
pkl[pkl["2023 Team"]=="U Mumba"]
# Out:
#      Unnamed: 0               Player Name     Category  Base Price Sold Price  \
# 203         203       Girish Maruti Ernak     Defender      20 lac       20.0
# 204         204            Mahender Singh     Defender      20 lac      40.25
# 205         205               Guman Singh       Raider      20 lac       85.0
# 206         206              Visvanath V.  All-Rounder      13 lac       13.0
# 207         207             Saurav Parthe       Raider       9 lac        9.0
# 208         208               Rohit Yadav       Raider       9 lac        9.0
# 209         209  Amirmohammad Zafardanesh  All-Rounder      13 lac       68.0
# 210         210         Alireza Mirzaeian       Raider      13 lac       16.1
# 211         211                     Kunal       Raider       9 lac        9.0
# 212         212                    Shivam       Raider  Category C   Retained
# 213         213               Jai Bhagwan       Raider  Category C   Retained
# ...

# %%
pkl[pkl["2023 Team"]=="U.P. Yoddhas " ]
# Out:
#      Unnamed: 0            Player Name     Category  Base Price Sold Price  \
# 225         225            Vijay Malik  All-Rounder      30 lac       85.0
# 226         226                Gurdeep  All-Rounder      20 lac       20.0
# 227         227           Nitin Panwar  All-Rounder      13 lac       13.0
# 228         228     Kiran Laxman Magar     Defender      13 lac       13.0
# 229         229         Harendra Kumar     Defender      13 lac       13.0
# 230         230          Gulveer Singh       Raider      13 lac       13.0
# 231         231  Helvic Simuyu Wanjala  All-Rounder      13 lac       13.0
# 232         232  Samuel Wanjala Wafula  All-Rounder      13 lac       13.0
# 233         233         Pardeep Narwal       Raider  Category A   Retained
# 234         234          Surender Gill       Raider  Category A   Retained
# 235         235                Mahipal       Raider         NYP   Retained
# ...
